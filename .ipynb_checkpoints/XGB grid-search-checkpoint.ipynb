# %%
import os 
import pandas as pd 
import numpy as np
from sklearn.svm import SVC
from sklearn.svm import OneClassSVM
import dask.dataframe as dd
import fastparquet
from imblearn.under_sampling import ClusterCentroids
from sklearn.model_selection import RepeatedStratifiedKFold
from joblib import Parallel, delayed
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from xgboost import XGBRFClassifier
from imblearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.under_sampling import OneSidedSelection
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

try:
    os.chdir("C:/Users/Sam/Documents/SISE/Fouille de données")
except:
    os.chdir("/Users/titouanhoude/Documents/GitHub")
    
XBdSada = pd.read_csv('Xtrain_Adasyn.csv')
XBdSada = XBdSada.drop(['Unnamed: 0'], axis = 1)

YBdada = pd.read_csv('Ytrain_Adasyn.csv')
YBdada = YBdada.drop(['Unnamed: 0'], axis = 1)

test = pd.read_parquet('test.parquet.gzip')

Xtest  = test.drop(["FlagImpaye","ZIBZIN", "Date", "Heure_split", "DateTransaction", 'Unnamed: 0'], axis = 1)
Ytest  = test.FlagImpaye

# %%
import os 
import pandas as pd 
import numpy as np
from sklearn.svm import SVC
from sklearn.svm import OneClassSVM
import dask.dataframe as dd
import fastparquet
from imblearn.under_sampling import ClusterCentroids
from sklearn.model_selection import RepeatedStratifiedKFold
from joblib import Parallel, delayed
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from xgboost import XGBRFClassifier
from imblearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.under_sampling import OneSidedSelection
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

try:
    os.chdir("C:/Users/Sam/Documents/GitHub/FouilleDonneeMassive/Xgboost")
    
except:
    os.chdir("/Users/titouanhoude/Documents/GitHub")
    
XBdSada = pd.read_csv('Xtrain_smote.csv')
XBdSada = XBdSada.drop(['Unnamed: 0'], axis = 1)

YBdada = pd.read_csv('Ytrain_smote.csv')
YBdada = YBdada.drop(['Unnamed: 0'], axis = 1)

os.chdir("C:/Users/Sam/Documents/SISE/Fouille de données")
test = pd.read_parquet('test.parquet.gzip')

Xtest  = test.drop(["FlagImpaye","ZIBZIN", "Date", "Heure_split", "DateTransaction", 'Unnamed: 0'], axis = 1)
Ytest  = test.FlagImpaye

# %%
XBdSada
# Out:
#          IDAvisAutorisationCheque     Montant  CodeDecision  VerifianceCPT1  \
# 0                        78643044   20.000000             1        0.000000
# 1                        78643045   20.000000             1        0.000000
# 2                        78643046   58.000000             1        0.000000
# 3                        78643047   54.000000             0        1.000000
# 4                        78643048   27.000000             1        0.000000
# ...                           ...         ...           ...             ...
# 7751875                  80355537   40.250167             1        0.544127
# 7751876                  80568862  120.814636             1        1.000000
# 7751877                  79082566  233.000000             0        2.000000
# 7751878                  80521256   44.114930             0        0.822986
# 7751879                  79596901  149.515516             2        6.959058
#
#          VerifianceCPT2  VerifianceCPT3        D2CB  ScoringFP1  ScoringFP2  \
# 0              0.000000        0.000000  551.000000    0.000000    0.000000
# 1              0.000000        0.000000  551.000000    0.000000    0.000000
# 2              0.000000        0.000000  549.000000    0.000000    0.000000
# 3              1.000000        1.000000  267.000000    0.000000    0.000000
# 4              0.000000        0.000000  549.000000    0.000000    9.000000
# ...                 ...             ...         ...         ...         ...
# 7751875        0.544127        0.544127  264.924335    0.000000    6.191108
# 7751876        1.000000        1.000000    1.000000    5.302333  -10.581655
# 7751877        2.000000        2.000000    7.000000    2.000000  -27.000000
# 7751878        2.468958        5.760902   17.204729    0.000000    0.000000
# 7751879       21.856702       21.856702    6.241263    3.972705  -22.829407
#
#          ScoringFP3  TauxImpNb_RB  TauxImpNB_CPM  EcartNumCheq  NbrMagasin3J  \
# 0               0.0     37.000000      52.000000      0.000000      1.000000
# 1               0.0     49.000000      52.000000      1.000000      2.000000
# 2               0.0     73.000000      52.000000      0.000000      1.000000
# 3               0.0    110.000000      54.000000      0.000000      1.000000
# 4               0.0     45.000000      52.000000      1.000000      1.000000
# ...             ...           ...            ...           ...           ...
# 7751875         0.0     97.751171      40.808892      0.000000      1.000000
# 7751876         1.0     49.395653      48.581336      0.000000      1.000000
# 7751877         0.0     37.000000      51.000000      0.000000      1.000000
# 7751878         0.0    177.500744      62.698818      0.000000      1.000000
# 7751879         0.0     46.883997      67.836231     38.733875      2.986353
#
#          DiffDateTr1  DiffDateTr2  DiffDateTr3  CA3TRetMtt     CA3TR  \
# 0           4.000000     4.000000     4.000000   20.000000    0.0000
# 1           2.000000     4.000000     4.000000   29.000000    9.0000
# 2           4.000000     4.000000     4.000000   58.000000    0.0000
# 3           4.000000     4.000000     4.000000   54.000000    0.0000
# 4           2.000000     4.000000     4.000000   59.000000   32.0000
# ...              ...          ...          ...         ...       ...
# 7751875     4.000000     4.000000     4.000000   40.250167    0.0000
# 7751876     5.000000     5.000000     5.000000  120.814636    0.0000
# 7751877     4.000000     4.000000     4.000000  233.000000    0.0000
# 7751878     4.000000     4.000000     4.000000   44.114930    0.0000
# 7751879     0.027295     1.020471     2.013647  438.529816  289.0143
#
#                 Heure
# 0        27134.000000
# 1        27817.000000
# 2        28058.000000
# 3        28128.000000
# 4        29607.000000
# ...               ...
# 7751875  56794.942948
# 7751876  75286.746242
# 7751877  56428.000000
# 7751878  56939.091287
# 7751879  62769.105441
#
# [7751880 rows x 20 columns]

# %%
parameters = {
        'gamma': [0, 0.5, 1],
        'max_depth': [3, 4, 5, 6],
        'learning_rate': [0.3, 0.1, 0.01, 0.05],
        
        }

crossvalidation=KFold(n_splits=2,shuffle=True,random_state=1)

def gridsearch(model):

    search1=GridSearchCV(estimator=model,param_grid=parameters,n_jobs=1,cv=crossvalidation)
    search1.fit(XBdSada,YBdada)
    
    return search1
    
results = Parallel(n_jobs=4)(delayed(gridsearch)(XGBRFClassifier()) for _ in range(1))

# %%
results[0].best_params_
res =results[0].best_params_
res = pd.DataFrame(res,index=[0]).transpose()
res.to_csv("C:/Users/Sam/Documents/GitHub/FouilleDonneeMassive/Xgboost/BestParam_Smote_Xgboost.csv")

# %%
pred_best = results[0].predict(Xtest)

# %%
from sklearn.metrics import classification_report
tab = classification_report(Ytest, pred_best,output_dict=True)
tab = pd.DataFrame(tab).transpose()
tab.to_csv("C:/Users/Sam/Documents/GitHub/FouilleDonneeMassive/Xgboost/Tab_SmoteGridSearch.csv")

# %%
parameters = {
        'gamma': [1,1.5, 2, 5],
        'max_depth': [6, 7, 8],
        'learning_rate': [0.3,0.4,0.6],
        
        }
results2 = Parallel(n_jobs=4)(delayed(gridsearch)(XGBRFClassifier()) for _ in range(1))
# Out:
# {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 6}
